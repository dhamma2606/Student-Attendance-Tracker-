# %%
import numpy as np
import pandas as pd
students = pd.read_csv("/content/students (1).csv")["Name"].values
n_students = len(students)
days = 30

prob_present = np.concatenate([
    np.full(n_students // 2, 0.8),
    np.full(n_students - n_students // 2, 0.4)
])

att = np.array([
    np.random.choice(['P', 'A'], p=[p, 1 - p], size=days)
    for p in prob_present
])

dates = pd.date_range(start='2025-09-01', periods=days).strftime('%d-%m-%Y')

df = pd.DataFrame(att, index=students, columns=dates)

total_present = (att == 'P').sum(axis=1)
total_absent = (att == 'A').sum(axis=1)
percent = total_present / days * 100
status = np.where(percent >= 75, 'Qualified', 'Disqualified')

df['Total_Present'] = total_present
df['Total_Absent'] = total_absent
df['Percent_Attendance'] = percent
df['Status'] = status

daily_info = pd.DataFrame({
    'Presentees': [', '.join(df.index[att[:, i] == 'P']) for i in range(days)],
    'Absentees': [', '.join(df.index[att[:, i] == 'A']) for i in range(days)],
    'Total_Presentees': (att == 'P').sum(axis=0),
    'Total_Absentees': (att == 'A').sum(axis=0)
}, index=dates)

print("\n--- All Students Attendance ---\n", df)
print("\n--- Daily Presentees & Absentees with Counts ---\n", daily_info)

df.to_csv("students_attendance.csv", index=True)
daily_info.to_csv("daily_attendance_summary.csv", index=True)
# Out:
# --- All Students Attendance ---
#            01-09-2025 02-09-2025 03-09-2025 04-09-2025 05-09-2025 06-09-2025  \
# Giri               P          P          P          P          P          A
# Neha               P          P          P          P          P          P
# Sradha             A          P          P          P          A          A
# Zu-Dhamma          P          P          P          P          P          P
# Rukmini            A          P          A          P          P          P
# Shankar            P          A          P          P          P          P
# Sruthi             P          P          P          P          P          P
# Vaheetha           P          P          A          P          P          P
# Fathima            P          P          A          P          A          P
# Anakha             P          P          P          P          A          P
# Aditya             P          P          P          P          P          A
# Priya              P          A          P          P          A          P
# Rohan              A          P          A          A          A          P
# Diya               A          P          A          P          P          P
# Kavya              P          A          P          A          A          P
# Varun              P          A          P          P          P          A
# Anika              A          P          A          P          A          A
# Sai                A          A          A          P          A          P
# Ria                A          A          A          A          P          A
# Arnav              A          A          P          P          A          A
# Maya               A          A          P          A          A          A
# Krishna            A          P          P          P          A          P
# Tara               A          A          A          A          A          P
# Aryan              A          P          A          A          A          A
# Madhu              P          A          P          A          A          A
#
#           07-09-2025 08-09-2025 09-09-2025 10-09-2025  ... 25-09-2025  \
# Giri               P          P          P          P  ...          P
# Neha               P          P          P          P  ...          P
# Sradha             P          P          P          P  ...          A
# Zu-Dhamma          P          P          P          P  ...          P
# Rukmini            A          P          P          P  ...          P
# Shankar            P          P          A          P  ...          P
# Sruthi             P          A          A          P  ...          P
# Vaheetha           P          A          A          A  ...          P
# Fathima            P          P          P          A  ...          P
# Anakha             P          P          P          P  ...          A
# Aditya             P          P          A          A  ...          P
# Priya              P          P          P          P  ...          P
# Rohan              A          A          P          P  ...          A
# Diya               A          P          P          P  ...          A
# Kavya              A          A          A          A  ...          A
# Varun              P          A          A          P  ...          A
# Anika              A          A          P          P  ...          A
# Sai                P          P          A          A  ...          A
# Ria                A          A          P          A  ...          P
# Arnav              P          A          P          P  ...          P
# Maya               P          A          A          P  ...          A
# Krishna            P          P          A          A  ...          A
# Tara               A          A          A          A  ...          A
# Aryan              A          A          P          P  ...          A
# Madhu              A          A          A          P  ...          A
#
#           26-09-2025 27-09-2025 28-09-2025 29-09-2025 30-09-2025  \
# Giri               P          P          P          P          P
# Neha               P          P          P          P          P
# Sradha             A          P          P          P          P
# Zu-Dhamma          P          A          P          P          A
# Rukmini            P          P          P          P          P
# Shankar            P          P          A          P          P
# Sruthi             P          P          P          P          P
# Vaheetha           P          P          A          A          P
# Fathima            P          P          P          P          A
# Anakha             P          P          P          P          P
# Aditya             P          A          P          P          P
# Priya              P          P          P          A          P
# Rohan              P          P          P          A          A
# Diya               A          A          A          P          P
# Kavya              A          A          A          A          P
# Varun              A          A          A          A          A
# Anika              A          P          P          P          P
# Sai                A          A          A          P          A
# Ria                A          A          A          P          A
# Arnav              A          A          A          P          A
# Maya               A          A          A          A          P
# Krishna            P          P          P          A          A
# Tara               A          A          A          P          A
# Aryan              A          A          A          P          A
# Madhu              P          A          P          A          A
#
#           Total_Present Total_Absent Percent_Attendance        Status
# Giri                 27            3          90.000000     Qualified
# Neha                 27            3          90.000000     Qualified
# Sradha               25            5          83.333333     Qualified
# Zu-Dhamma            25            5          83.333333     Qualified
# Rukmini              23            7          76.666667     Qualified
# Shankar              24            6          80.000000     Qualified
# Sruthi               26            4          86.666667     Qualified
# Vaheetha             22            8          73.333333  Disqualified
# Fathima              22            8          73.333333  Disqualified
# Anakha               27            3          90.000000     Qualified
# Aditya               21            9          70.000000  Disqualified
# Priya                24            6          80.000000     Qualified
# Rohan                12           18          40.000000  Disqualified
# Diya                 12           18          40.000000  Disqualified
# Kavya                12           18          40.000000  Disqualified
# Varun                12           18          40.000000  Disqualified
# Anika                14           16          46.666667  Disqualified
# Sai                  10           20          33.333333  Disqualified
# Ria                  14           16          46.666667  Disqualified
# Arnav                13           17          43.333333  Disqualified
# Maya                  8           22          26.666667  Disqualified
# Krishna              14           16          46.666667  Disqualified
# Tara                  5           25          16.666667  Disqualified
# Aryan                11           19          36.666667  Disqualified
# Madhu                12           18          40.000000  Disqualified
#
# [25 rows x 34 columns]
#
# --- Daily Presentees & Absentees with Counts ---
#                                                     Presentees  \
# 01-09-2025  Giri, Neha, Zu-Dhamma, Shankar, Sruthi, Vaheet...
# 02-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Sruthi...
# 03-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Shankar, Sruthi...
# 04-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 05-09-2025  Giri, Neha, Zu-Dhamma, Rukmini, Shankar, Sruth...
# 06-09-2025  Neha, Zu-Dhamma, Rukmini, Shankar, Sruthi, Vah...
# 07-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Shankar, Sruthi...
# 08-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 09-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Fathim...
# 10-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 11-09-2025  Giri, Neha, Sradha, Shankar, Sruthi, Vaheetha,...
# 12-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Shankar, Sruthi...
# 13-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 14-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 15-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 16-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Shankar, Sruthi...
# 17-09-2025  Giri, Neha, Sradha, Shankar, Sruthi, Vaheetha,...
# 18-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 19-09-2025  Giri, Sradha, Rukmini, Fathima, Anakha, Aditya...
# 20-09-2025  Neha, Sradha, Zu-Dhamma, Rukmini, Sruthi, Vahe...
# 21-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 22-09-2025  Sradha, Zu-Dhamma, Rukmini, Shankar, Sruthi, V...
# 23-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 24-09-2025  Giri, Sradha, Zu-Dhamma, Rukmini, Sruthi, Fath...
# 25-09-2025  Giri, Neha, Zu-Dhamma, Rukmini, Shankar, Sruth...
# 26-09-2025  Giri, Neha, Zu-Dhamma, Rukmini, Shankar, Sruth...
# 27-09-2025  Giri, Neha, Sradha, Rukmini, Shankar, Sruthi, ...
# 28-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini,