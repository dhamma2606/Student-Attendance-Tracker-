# %%
import numpy as np
import pandas as pd

students = pd.read_csv("students.csv")["Name"].values
n_students = len(students)
days = 30

prob_present = np.concatenate([np.full(n_students//2, 0.8), np.full(n_students - n_students//2, 0.4)])
att = np.array([np.random.choice(['P','A'], p=[p, 1-p], size=days) for p in prob_present])

dates = pd.date_range(start='2025-09-01', periods=days).strftime('%d-%m-%Y')

df = pd.DataFrame(att, index=students, columns=dates)

total_present = (att=='P').sum(axis=1)
total_absent  = (att=='A').sum(axis=1)
percent = total_present / days * 100
status = np.where(percent >= 75, 'Qualified', 'Disqualified')

df['Total_Present'] = total_present
df['Total_Absent'] = total_absent
df['Percent_Attendance'] = percent
df['Status'] = status

daily_info = pd.DataFrame({
    'Presentees': [', '.join(df.index[att[:,i]=='P']) for i in range(days)],
    'Absentees': [', '.join(df.index[att[:,i]=='A']) for i in range(days)],
    'Total_Presentees': (att=='P').sum(axis=0),
    'Total_Absentees': (att=='A').sum(axis=0)
}, index=dates)

print("\n--- All Students Attendance ---\n", df)
print("\n--- Daily Presentees & Absentees with Counts ---\n", daily_info)

df.to_csv("students_attendance.csv")
daily_info.to_csv("daily_attendance_summary.csv")
# Out:
# --- All Students Attendance ---
#            01-09-2025 02-09-2025 03-09-2025 04-09-2025 05-09-2025 06-09-2025  \
# Giri               P          A          P          P          P          A
# Neha               P          P          P          P          P          P
# Sradha             P          P          P          P          P          P
# Zu-Dhamma          P          P          P          P          P          P
# Rukmini            A          A          A          P          P          P
# Shankar            A          P          P          P          P          P
# Sruthi             A          A          A          A          A          P
# Vaheetha           A          A          A          P          A          A
# Fathima            A          P          P          A          P          P
# Anakha             A          A          P          P          P          P
# Aditya             P          A          P          P          P          P
# Priya              P          P          P          P          P          P
# Rohan              A          A          A          A          P          P
# Diya               P          A          A          A          A          A
# Kavya              P          P          A          P          P          A
# Varun              P          A          A          P          A          A
# Anika              P          A          A          P          P          P
# Sai                A          A          A          P          P          A
# Ria                P          A          A          A          P          A
# Arnav              A          P          A          A          A          P
# Maya               P          P          P          P          A          A
# Krishna            A          P          P          A          A          P
# Tara               A          P          A          P          A          A
# Aryan              A          P          P          P          A          A
#
#           07-09-2025 08-09-2025 09-09-2025 10-09-2025  ... 25-09-2025  \
# Giri               P          P          P          P  ...          P
# Neha               P          P          P          A  ...          A
# Sradha             P          P          A          P  ...          A
# Zu-Dhamma          A          P          P          P  ...          A
# Rukmini            P          P          P          P  ...          P
# Shankar            P          P          A          P  ...          P
# Sruthi             P          P          P          A  ...          P
# Vaheetha           P          P          A          P  ...          P
# Fathima            A          P          P          P  ...          P
# Anakha             P          P          P          A  ...          P
# Aditya             P          P          P          A  ...          P
# Priya              A          P          P          A  ...          P
# Rohan              A          P          A          P  ...          A
# Diya               A          A          P          A  ...          A
# Kavya              A          A          P          A  ...          P
# Varun              A          A          P          A  ...          P
# Anika              P          A          P          A  ...          P
# Sai                A          A          A          A  ...          P
# Ria                A          P          A          A  ...          P
# Arnav              A          A          A          A  ...          A
# Maya               A          P          P          A  ...          P
# Krishna            P          A          A          P  ...          P
# Tara               A          A          A          A  ...          P
# Aryan              A          P          P          P  ...          A
#
#           26-09-2025 27-09-2025 28-09-2025 29-09-2025 30-09-2025  \
# Giri               P          A          P          P          P
# Neha               P          P          P          P          P
# Sradha             A          P          P          P          A
# Zu-Dhamma          A          P          A          A          P
# Rukmini            A          A          P          A          P
# Shankar            P          P          P          P          P
# Sruthi             P          P          P          A          P
# Vaheetha           A          A          P          A          P
# Fathima            P          P          A          P          P
# Anakha             A          A          P          P          A
# Aditya             A          P          P          P          P
# Priya              A          P          P          A          P
# Rohan              P          A          A          A          A
# Diya               A          A          P          A          P
# Kavya              P          P          P          A          A
# Varun              A          P          P          P          A
# Anika              A          P          A          P          A
# Sai                A          P          A          P          A
# Ria                A          A          P          A          A
# Arnav              A          P          A          A          A
# Maya               A          A          P          P          A
# Krishna            P          P          A          A          A
# Tara               A          P          A          A          A
# Aryan              A          A          A          P          A
#
#           Total_Present Total_Absent Percent_Attendance        Status
# Giri                 25            5          83.333333     Qualified
# Neha                 23            7          76.666667     Qualified
# Sradha               22            8          73.333333  Disqualified
# Zu-Dhamma            23            7          76.666667     Qualified
# Rukmini              22            8          73.333333  Disqualified
# Shankar              26            4          86.666667     Qualified
# Sruthi               19           11          63.333333  Disqualified
# Vaheetha             18           12          60.000000  Disqualified
# Fathima              23            7          76.666667     Qualified
# Anakha               24            6          80.000000     Qualified
# Aditya               24            6          80.000000     Qualified
# Priya                24            6          80.000000     Qualified
# Rohan                10           20          33.333333  Disqualified
# Diya                  9           21          30.000000  Disqualified
# Kavya                15           15          50.000000  Disqualified
# Varun                13           17          43.333333  Disqualified
# Anika                16           14          53.333333  Disqualified
# Sai                  12           18          40.000000  Disqualified
# Ria                  15           15          50.000000  Disqualified
# Arnav                 9           21          30.000000  Disqualified
# Maya                 17           13          56.666667  Disqualified
# Krishna              12           18          40.000000  Disqualified
# Tara                  9           21          30.000000  Disqualified
# Aryan                 9           21          30.000000  Disqualified
#
# [24 rows x 34 columns]
#
# --- Daily Presentees & Absentees with Counts ---
#                                                     Presentees  \
# 01-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Aditya, Priya, ...
# 02-09-2025  Neha, Sradha, Zu-Dhamma, Shankar, Fathima, Pri...
# 03-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Shankar, Fathim...
# 04-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 05-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 06-09-2025  Neha, Sradha, Zu-Dhamma, Rukmini, Shankar, Sru...
# 07-09-2025  Giri, Neha, Sradha, Rukmini, Shankar, Sruthi, ...
# 08-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 09-09-2025  Giri, Neha, Zu-Dhamma, Rukmini, Sruthi, Fathim...
# 10-09-2025  Giri, Sradha, Zu-Dhamma, Rukmini, Shankar, Vah...
# 11-09-2025  Giri, Sradha, Zu-Dhamma, Rukmini, Shankar, Sru...
# 12-09-2025  Giri, Neha, Zu-Dhamma, Rukmini, Shankar, Vahee...
# 13-09-2025  Giri, Sradha, Rukmini, Shankar, Sruthi, Fathim...
# 14-09-2025  Giri, Neha, Zu-Dhamma, Rukmini, Shankar, Sruth...
# 15-09-2025  Giri, Sradha, Zu-Dhamma, Rukmini, Shankar, Ana...
# 16-09-2025  Neha, Sradha, Zu-Dhamma, Rukmini, Sruthi, Fath...
# 17-09-2025  Giri, Zu-Dhamma, Rukmini, Vaheetha, Anakha, Ad...
# 18-09-2025  Giri, Sradha, Zu-Dhamma, Rukmini, Shankar, Sru...
# 19-09-2025  Neha, Sradha, Zu-Dhamma, Shankar, Sruthi, Vahe...
# 20-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 21-09-2025  Giri, Neha, Zu-Dhamma, Rukmini, Shankar, Sruth...
# 22-09-2025  Giri, Neha, Sradha, Shankar, Sruthi, Vaheetha,...
# 23-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 24-09-2025  Giri, Neha, Sradha, Zu-Dhamma, Rukmini, Shanka...
# 25-09-2025  Giri, Rukmini, Shankar, Sruthi, Vaheetha, Fath...
# 26-09-2025  Giri, Neha, Shankar, Sruthi, Fathima, Rohan, K...
# 27-09-2025  Neha, Sradha, Zu-Dhamma, Shankar, Sruthi, Fath...
# 28-09-2025  Giri, Neha, Sradha, Rukmini, Shankar, Sruthi, ...
# 29-09-2025  Giri, Neha, Sradha, Shankar, Fathima, Anakha, ...
# 30-09-2025  Giri, Neha, Zu-Dhamma, Rukmini,